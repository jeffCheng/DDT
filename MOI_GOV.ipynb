# %%
import pandas as pd

# %%
#下載【內政部不動產時價登錄網 】中,位於【臺北市/新北市/桃園市/臺中市/高雄市】的
#【不動產買賣】資料,請選擇【本期下載】。
#使用【pandas】套件,讀取檔名【 a_lvr_land_a 】【 b_lvr_land_a 】 【 e_lvr_land_a 】
#【 f_lvr_land_a 】 【 h_lvr_land_a 】五份資料集,建立 dataframe 物件【df_a】【df_b】
#【df_e】【df_f】 【df_h】

# %%
df_a = pd.read_csv("download/a_lvr_land_a.csv", skiprows=[1], encoding="utf-8")
df_a.insert(0, '縣市', '臺北市')
df_b = pd.read_csv("download/b_lvr_land_a.csv", skiprows=[1], encoding="utf-8")
df_b.insert(0, '縣市', '臺中市')
df_e = pd.read_csv("download/e_lvr_land_a.csv", skiprows=[1], encoding="utf-8")
df_e.insert(0, '縣市', '高雄市')
df_f = pd.read_csv("download/f_lvr_land_a.csv", skiprows=[1], encoding="utf-8")
df_f.insert(0, '縣市', '新北市')
df_h = pd.read_csv("download/h_lvr_land_a.csv", skiprows=[1], encoding="utf-8")
df_h.insert(0, '縣市', '桃園市')

# %%
# 3. 操作 dataframe 物件,將五個物件合併成【df_all】。
# pd.set_option('display.max_columns', None)
df_all = pd.concat([df_a, df_b,df_e,df_f,df_h])

# %%
df_all.head()
# Out:
#     縣市 鄉鎮市區          交易標的   土地區段位置建物區段門牌  土地移轉總面積平方公尺  \
# 0  臺北市  文山區  房地(土地+建物)+車位  木新路二段43巷1~30號        64.97
# 1  臺北市  文山區  房地(土地+建物)+車位  木柵路四段33巷1~30號        13.33
# 2  臺北市  文山區  房地(土地+建物)+車位   萬芳路107巷1~30號        20.61
# 3  臺北市  文山區     房地(土地+建物)  新光路一段151~180號        25.33
# 4  臺北市  萬華區     房地(土地+建物)     國興路1巷1~30號        12.40
#
#                                             都市土地使用分區 非都市土地使用分區 非都市土地使用編定  \
# 0                                      都市：其他:第三種住宅區。       NaN       NaN
# 1                                      都市：其他:第三種住宅區。       NaN       NaN
# 2                                      都市：其他:第三種住宅區。       NaN       NaN
# 3                                      都市：其他:第三種住宅區。       NaN       NaN
# 4  都市：其他:第三之二種住宅區及第三之一種住宅區及第三種住宅區(是否在公共設施用地應依建築線或...       NaN       NaN
#
#      交易年月日      交易筆棟數  ...   車位類別 車位移轉總面積(平方公尺)    車位總價元          備註  \
# 0  1100127  土地1建物1車位1  ...   坡道平面         47.10  2500000         NaN
# 1  1100403  土地1建物1車位1  ...   坡道平面          0.00        0         NaN
# 2  1100403  土地1建物1車位1  ...   坡道機械         17.08        0         NaN
# 3  1100412  土地2建物1車位0  ...    NaN          0.00        0         NaN
# 4  1100206  土地1建物1車位0  ...    NaN          0.00        0  陽台外推；其他增建；
#
#                     編號   主建物面積  附屬建物面積   陽台面積  電梯  移轉編號
# 0  RPQNMLKMLHGGFAA66DA  120.26   17.84  18.31   有   NaN
# 1  RPPNMLNKMHGGFAA76DA   29.79    8.14   0.00   有   NaN
# 2  RPWPMLQKMHGGFAA97DA   55.80    5.78   4.13   有   1.0
# 3  RPWNMLSLMHGGFAA08DA   78.06    6.41  12.48   有   2.0
# 4  RPOPMLLKLHGGFBA66DA   31.51    0.00   3.78   有   3.0
#
# [5 rows x 34 columns]

# %%
# 4. 以下列條件從【df_all】篩選/計算出結果,並分別輸出【csv 檔案】 :
#filter_a.csv
#-【主要用途】為【住家用】
df_filter_a = df_all.loc[df_all['主要用途'] == '住家用']

# %%
#-【建物型態】為【住宅大樓】
df_filter_a = df_filter_a.loc[df_filter_a['建物型態'].str.contains("住宅大樓")]

# %%
#-【總樓層數】需【大於等於十三層】
def convertChineseDigit(chineseDigit):
    total= 0
    current_sum = 0
    
    for c in chineseDigit:
        digit = " ㄧ二三四五六七八九十百".find(c)
        if digit <= 9:
            current_sum = digit
        elif digit == 10:
            if current_sum > 0:
                total+= current_sum*10
            else:
                total+= 1*10
            current_sum = 0
        elif digit == 11:
            total+=current_sum*100
            current_sum = 0
    return total+current_sum

# %%
df_filter_a['Int_Floor'] = df_filter_a.apply(lambda x: convertChineseDigit(x['總樓層數'][:-1]), axis=1)

# %%
df_filter_a = df_filter_a.loc[df_filter_a['Int_Floor'] >= 13]
pd.set_option('display.max_columns', None)
df_filter_a.head()
# Out:
#      縣市 鄉鎮市區          交易標的        土地區段位置建物區段門牌  土地移轉總面積平方公尺  \
# 25  臺北市  內湖區  房地(土地+建物)+車位       星雲街150巷31~60號        21.90
# 27  臺北市  內湖區  房地(土地+建物)+車位      成功路五段450巷1~30號        27.33
# 32  臺北市  南港區  房地(土地+建物)+車位  經貿二路157巷36弄91~120號        57.95
# 42  臺北市  南港區  房地(土地+建物)+車位        研究院路二段61~90號        42.43
# 45  臺北市  信義區     房地(土地+建物)            松勤街1~30號         6.04
#
#                                  都市土地使用分區 非都市土地使用分區 非都市土地使用編定    交易年月日  \
# 25                          都市：其他:第三種住宅區。       NaN       NaN  1100315
# 27  都市：其他:第三之二種住宅區(依都市計畫說明書圖規定辦理)及第三種住宅區。       NaN       NaN  1100402
# 32                    都市：其他:住宅區(供商務住宅使用)。       NaN       NaN  1100325
# 42                          都市：其他:第三種住宅區。       NaN       NaN  1100328
# 45                都市：其他:特定業務區(信義計畫特定專用區)。       NaN       NaN  1100328
#
#         交易筆棟數      移轉層次  總樓層數             建物型態 主要用途    主要建材     建築完成年月  \
# 25  土地1建物1車位1        八層  二十四層  住宅大樓(11層含以上有電梯)  住家用   見使用執照   870717.0
# 27  土地1建物1車位1        七層   十四層  住宅大樓(11層含以上有電梯)  住家用  鋼筋混凝土造   881022.0
# 32  土地1建物1車位2  二十層，二十一層  二十一層  住宅大樓(11層含以上有電梯)  住家用  鋼筋混凝土造  1030306.0
# 42  土地1建物1車位1       十二層   十三層  住宅大樓(11層含以上有電梯)  住家用  鋼筋混凝土造  1020603.0
# 45  土地1建物1車位0       十六層   十九層  住宅大樓(11層含以上有電梯)  住家用     鋼骨造   961225.0
#
#     建物移轉總面積平方公尺  建物現況格局-房  建物現況格局-廳  建物現況格局-衛 建物現況格局-隔間 有無管理組織       總價元  \
# 25       169.95         2         2         1         有      有  25320000
# 27       167.61         3         2         2         有      有  34580000
# 32       379.70         3         3         2         有      有  87100000
# 42       269.75         4         2         2         有      有  42160000
# 45        48.46         1         1         1         有      有  19350000
#
#      單價元平方公尺  車位類別  車位移轉總面積(平方公尺)    車位總價元                 備註  \
# 25  148985.0  坡道平面           0.00        0         陽台外推；其他增建；
# 27  206312.0  坡道平面           0.00        0                NaN
# 32  280274.0  坡道平面          90.34  6000000                NaN
# 42  159245.0  坡道平面          14.42  1500000  預售屋、或土地及建物分次登記案件；
# 45  399298.0   NaN           0.00        0              陽台外推；
#
#                      編號   主建物面積  附屬建物面積   陽台面積 電梯  移轉編號  Int_Floor
# 25  RPPNMLTLMHGGFCA67DA   60.63    0.00   3.70  有  13.0         24
# 27  RPSNMLTLMHGGFCA97DA   88.66    0.00   9.17  有   NaN         14
# 32  RPSNMLMLLHGGFDA27DA  179.74   11.86  12.92  有   NaN         19
# 42  RPPQMLRLMHGGFDA87DA  135.66    9.76  13.81  有   NaN         13
# 45  RPVNMLTLMHGGFDA38DA   27.76    0.49   3.72  有  23.0         19

# %%
# df_filter_a
df_filter_a.to_csv(r'filter_a.csv', index = False)

# %%
#* filter_b.csv
#- 計算【總件數】
len(df_all)
# Out:
# 5600

# %%
#- 計算【總車位數】(透過交易筆棟數)
def cal_parking_lot(transaction_count:str):
    return transaction_count[transaction_count.index('車位')+2:]

# %%
df_all['Parking_lot'] = df_all.apply(lambda x: cal_parking_lot(x['交易筆棟數']), axis=1)

# %%
df_all.head()
# Out:
#     縣市 鄉鎮市區          交易標的   土地區段位置建物區段門牌  土地移轉總面積平方公尺  \
# 0  臺北市  文山區  房地(土地+建物)+車位  木新路二段43巷1~30號        64.97
# 1  臺北市  文山區  房地(土地+建物)+車位  木柵路四段33巷1~30號        13.33
# 2  臺北市  文山區  房地(土地+建物)+車位   萬芳路107巷1~30號        20.61
# 3  臺北市  文山區     房地(土地+建物)  新光路一段151~180號        25.33
# 4  臺北市  萬華區     房地(土地+建物)     國興路1巷1~30號        12.40
#
#                                             都市土地使用分區 非都市土地使用分區 非都市土地使用編定  \
# 0                                      都市：其他:第三種住宅區。       NaN       NaN
# 1                                      都市：其他:第三種住宅區。       NaN       NaN
# 2                                      都市：其他:第三種住宅區。       NaN       NaN
# 3                                      都市：其他:第三種住宅區。       NaN       NaN
# 4  都市：其他:第三之二種住宅區及第三之一種住宅區及第三種住宅區(是否在公共設施用地應依建築線或...       NaN       NaN
#
#      交易年月日      交易筆棟數     ...      車位移轉總面積(平方公尺)    車位總價元          備註  \
# 0  1100127  土地1建物1車位1     ...              47.10  2500000         NaN
# 1  1100403  土地1建物1車位1     ...               0.00        0         NaN
# 2  1100403  土地1建物1車位1     ...              17.08        0         NaN
# 3  1100412  土地2建物1車位0     ...               0.00        0         NaN
# 4  1100206  土地1建物1車位0     ...               0.00        0  陽台外推；其他增建；
#
#                     編號   主建物面積  附屬建物面積   陽台面積  電梯  移轉編號  Parking_lot
# 0  RPQNMLKMLHGGFAA66DA  120.26   17.84  18.31   有   NaN            1
# 1  RPPNMLNKMHGGFAA76DA   29.79    8.14   0.00   有   NaN            1
# 2  RPWPMLQKMHGGFAA97DA   55.80    5.78   4.13   有   1.0            1
# 3  RPWNMLSLMHGGFAA08DA   78.06    6.41  12.48   有   2.0            0
# 4  RPOPMLLKLHGGFBA66DA   31.51    0.00   3.78   有   3.0            0
#
# [5 rows x 35 columns]

# %%
# df_all[['Parking_lot']].apply(pd.Series.value_counts)
df_all['Parking_lot'] = df_all['Parking_lot'].astype(int)
# 【總車位數】
df_all['Parking_lot'].sum()
# Out:
# 3018

# %%
#- 計算【平均總價元】
df_all['總價元'] = df_all['總價元'].astype(int)
df_all['總價元'].mean()
# Out:
# 14569953.79642857

# %%
#- 計算【平均車位總價元】
df_all['Total_Parking_Val'] = df_all['車位總價元']*df_all['Parking_lot']
df_all['Total_Parking_Val'].mean()
# Out:
# 724806.6071428572

# %%
filter_b_dicts = {'總件數':len(df_all),'總車位數':df_all['Parking_lot'].sum(),'平均總價元':round(df_all['總價元'].mean(),0),'平均車位總價元':round(df_all['Total_Parking_Val'].mean(),0)}

# %%
filter_b_dicts
# Out:
# {'平均總價元': 14569954.0, '平均車位總價元': 724807.0, '總件數': 5600, '總車位數': 3018}

# %%
# df_filter_a.to_csv(r'filter_a.csv', index = False)
pd.DataFrame([filter_b_dicts]).to_csv('filter_b.csv', index=False)
